# %% [markdown]
# # Task 1: Data Overview

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb b   
import warnings
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv("../cognifyz/Cognifyz Dataset.csv")

# %%
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.info()
#show number of entries and columns and their data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %% [markdown]
# # Task 2: Gender Distribution

# %%
tt=df["gender"].value_counts()

# %%
plt.figure(figsize=(5,5))
sb.countplot(data=df,x='gender')
           #hue=DEFINE THE PERTICULAR CALSS ,right side top create box
plt.title("distribution of gender",fontsize=10)
plt.xlabel("Gender",fontsize=10)
plt.ylabel("count",fontsize=10)
plt.show()

# %%
plt.figure(figsize=[5,5])
plt.pie(tt.values,labels=tt.index,autopct="%d%%")
plt.axis("equal")
plt.show()

# %% [markdown]
# From Above graph we can see that male distribution is more than female.

# %% [markdown]
# # Task 3: Descriptive Statistics

# %%
print(df.dtypes)
#show the numeric columns with the help of data types.
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
numeric_df=df.apply(pd.to_numeric,errors='coerce')
numeric_df
# Out:
#     gender  age  Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0      NaN   34                 NaN             1              2           5
# 1      NaN   23                 NaN             4              3           2
# 2      NaN   30                 NaN             3              6           4
# 3      NaN   22                 NaN             2              1           3
# 4      NaN   24                 NaN             2              1           3
# 5      NaN   24                 NaN             7              5           4
# 6      NaN   27                 NaN             3              6           4
# 7      NaN   21                 NaN             2              3           7
# 8      NaN   35                 NaN             2              4           7
# 9      NaN   31                 NaN             1              3           7
# 10     NaN   35                 NaN             2              4           7
# ...

# %%
#stastical functions
#age
print(df["age"].mean())
print(df["age"].median())
print(df["age"].std())
# Out:
# 27.8
# 27.0
# 3.560466693696639

# %%
#mutual_funds
print(df["Mutual_Funds"].mean())
print(df["Mutual_Funds"].median())
print(df["Mutual_Funds"].std())
# Out:
# 2.55
# 2.0
# 1.1972189997378648

# %%
#Equity_Market
print(df["Equity_Market"].mean())
print(df["Equity_Market"].median())
print(df["Equity_Market"].std())
# Out:
# 3.475
# 4.0
# 1.1319939294935533

# %%
#Debentures
print(df["Debentures"].mean())
print(df["Debentures"].median())
print(df["Debentures"].std())
# Out:
# 5.75
# 6.5
# 1.6756169931378433

# %%
#Government_Bonds
print(df["Government_Bonds"].mean())
print(df["Government_Bonds"].median())
print(df["Government_Bonds"].std())
# Out:
# 4.65
# 5.0
# 1.3690723042845383

# %%
#Fixed_Deposits
print(df["Fixed_Deposits"].mean())
print(df["Fixed_Deposits"].median())
print(df["Fixed_Deposits"].std())
# Out:
# 3.575
# 3.5
# 1.7958284996067968

# %%
#PPF
print(df["PPF"].mean())
print(df["PPF"].median())
print(df["PPF"].std())
# Out:
# 2.025
# 1.0
# 1.6090688500193404

# %%
#Gold
print(df["Gold"].mean())
print(df["Gold"].median())
print(df["Gold"].std())
# Out:
# 5.975
# 6.0
# 1.1432634351063986

# %%
#in short
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %% [markdown]
# from above  cells  I identified neumeric columns like age, mutual_funds,equity_market...etc and calculated mean,median,std,min,max..etc by using describe(),mean(),medium(),std(),to_numeric() methods.

# %% [markdown]
# # task 4: Most Preferred Investment Avenue

# %%
tt1=df["Investment_Avenues"].value_counts()
tt1
# Out:
# Yes    37
# No      3
# Name: Investment_Avenues, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.pie(tt1.values,labels=tt1.index,autopct="%d%%")
plt.show()

# %%
#gender and investment_avenues group 
group=df.groupby(["gender","Investment_Avenues"])
group.groups
# Out:
# {('Female', 'No'): [4, 5, 12], ('Female', 'Yes'): [0, 1, 6, 10, 13, 14, 16, 21, 24, 25, 29, 31], ('Male', 'Yes'): [2, 3, 7, 8, 9, 11, 15, 17, 18, 19, 20, 22, 23, 26, 27, 28, 30, 32, 33, 34, 35, 36, 37, 38, 39]}

# %%
ax = sb.countplot(x = 'Investment_Avenues',hue='gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
m=df.groupby("gender")["Mutual_Funds"].mean()
e=df.groupby("gender")["Equity_Market"].mean()
f=df.groupby("gender")["Fixed_Deposits"].mean()
g=df.groupby("gender")["Government_Bonds"].mean()
gold=df.groupby("gender")["Gold"].mean()
p=df.groupby("gender")["PPF"].mean()

# %%
fig=plt.figure(figsize=[10,15])
m1=fig.add_subplot(331)
sb.barplot(x=m.index,y=m.values)
plt.title("Mutual_Funds")
for bars in m1.containers:
    m1.bar_label(bars)

e1=fig.add_subplot(332)
sb.barplot(x=e.index,y=e.values)
plt.title("Equity_Market")
for bars in e1.containers:
    e1.bar_label(bars)


f1=fig.add_subplot(333)
sb.barplot(x=f.index,y=f.values)
plt.title("Fixed_Deposits")
for bars in f1.containers:
    f1.bar_label(bars)

g1=fig.add_subplot(334)
sb.barplot(x=g.index,y=g.values)
plt.title("Government_Bonds")
for bars in g1.containers:
    g1.bar_label(bars)

gold1=fig.add_subplot(335)
sb.barplot(x=gold.index,y=gold.values)
plt.title("Gold")
for bars in gold1.containers:
    gold1.bar_label(bars)
    
p1=fig.add_subplot(336)
sb.barplot(x=p.index,y=p.values)
plt.title("PPF")
for bars in p1.containers:
    p1.bar_label(bars)

plt.show()

# %% [markdown]
#  Analyze invesment avenues by using plots and from this graph we can see that most of the invesment in gold and then goverment _bonds therefore ,I prefred invesment Avenue  gold and goverment_bonds.

# %%
fig=plt.figure(figsize=[15,15])
K1=fig.add_subplot(331)
sb.kdeplot(x=df.Mutual_Funds)

K2=fig.add_subplot(332)
sb.kdeplot(x=df.Equity_Market)

K3=fig.add_subplot(333)
sb.kdeplot(x=df.Fixed_Deposits)


K4=fig.add_subplot(334)
sb.kdeplot(x=df.Government_Bonds)



K4=fig.add_subplot(335)
sb.kdeplot(x=df.Gold)


K5=fig.add_subplot(336)
sb.kdeplot(x=df.PPF)

plt.show()

# %% [markdown]
#  Analyze invesment avenues by using plots and from this graph we can see that most of the invesment in gold and then goverment _bonds therefore ,I prefred invesment Avenue  gold and goverment_bonds and also frequency is displayed in above every plot.

# %% [markdown]
# # Task 5: Reasons for Investment

# %%
#Reasons of every feilds.
print(df["Reason_Equity"].value_counts())
print("----------------------------------")
print(df["Reason_Mutual"].value_counts())
print("----------------------------------")
print(df["Reason_Bonds"].value_counts())
print("----------------------------------")
print(df["Reason_FD"].value_counts())
# Out:
# Capital Appreciation    30
# Dividend                 8
# Liquidity                2
# Name: Reason_Equity, dtype: int64
# ----------------------------------
# Better Returns          24
# Fund Diversification    13
# Tax Benefits             3
# Name: Reason_Mutual, dtype: int64
# ----------------------------------
# Assured Returns    26
# Safe Investment    13
# Tax Incentives      1
# Name: Reason_Bonds, dtype: int64
# ----------------------------------
# Risk Free              19
# Fixed Returns          18
# High Interest Rates     3
# Name: Reason_FD, dtype: int64

# %%
#Reasons of every feilds.
re=df["Reason_Equity"].value_counts()
rm=df["Reason_Mutual"].value_counts()
rb=df["Reason_Bonds"].value_counts()
rf=df["Reason_FD"].value_counts()

# %%
fig=plt.figure(figsize=[12,10])
m1=fig.add_subplot(221)
sb.countplot(x=df.Reason_Mutual)
plt.title("Reason_Mutual")
for bars in m1.containers:
    m1.bar_label(bars)

e1=fig.add_subplot(222)
sb.countplot(x=df.Reason_Equity)
plt.title("Reason_Equity")
for bars in e1.containers:
    e1.bar_label(bars)


f1=fig.add_subplot(223)
sb.countplot(x=df.Reason_FD)
plt.title("Reason_FD")
for bars in f1.containers:
    f1.bar_label(bars)

g1=fig.add_subplot(224)
sb.countplot(x=df.Reason_Bonds)
plt.title("Reason_Bonds")
for bars in g1.containers:
    g1.bar_label(bars)
plt.show()

# %% [markdown]
# from above graphs we can see that in equity_market capital Appreciation is one reason of most of the persons.
# and then better Returns in Mutual_Funds and Risk free in fixed_Deposite and assured return in goverment_bonds and also goverment_bonds tax incentives is very low.

# %% [markdown]
# # Task 6: Savings Objectives

# %%
df["What are your savings objectives?"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: What are your savings objectives?
# Non-Null Count  Dtype
# --------------  -----
# 40 non-null     object
# dtypes: object(1)
# memory usage: 448.0+ bytes

# %%
saving=df["What are your savings objectives?"].value_counts()
saving
# Out:
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: What are your savings objectives?, dtype: int64

# %%
plt.figure(figsize=[5,10])
k11=plt.pie(saving.values,labels=saving.index,autopct="%d%%")
plt.title("savings objectives")

plt.show().
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_8840\3196322367.py", line 5
#     plt.show().
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# I analyzed most of the participants saving objectives is Retirement Plan.

# %% [markdown]
# # Task 7: Common Information Sources

# %%
source=df["Source"].value_counts()
source

# %%
plt.figure(figsize=(5,10))
plt.pie(source.values,labels=source.index ,autopct="%d%%")
plt.show()

# %%
fig=plt.figure(figsize=(18,10))
msource=fig.add_subplot(221)
sb.barplot(x=df.Source,y=df.Mutual_Funds)
plt.title("Mutual_Funds")


msource=fig.add_subplot(222)
sb.barplot(x=df.Source,y=df.Equity_Market)
plt.title("Equity_Market")


msource=fig.add_subplot(223)
sb.barplot(x=df.Source,y=df.Debentures)
plt.title("Debentures")


msource=fig.add_subplot(224)
sb.barplot(x=df.Source,y=df.Government_Bonds)
plt.title("Government_Bonds")
plt.show()
#

# %% [markdown]
# from above graph we can see that Financial Consultants source is useful for most of the partcipants by using piechart.
# analyze the common source data and dislayed by using barplot based on different types to invesment Avenues.

# %% [markdown]
# # Task 8: Investment Duration

# %%
df["Duration"].info()

# %%
duration=df["Duration"].value_counts()
duration

# %%
plt.pie(duration.values,labels=duration.index,autopct="%d%%")
plt.show()

# %%
ax = sb.countplot(data = df, x = 'Duration', hue = 'gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Task 9: Expectations from Investments

# %%
df["Expect"].value_counts()

# %%
ax = sb.countplot(data = df, x = 'Expect', hue = 'gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
fig=plt.figure(figsize=(18,10))
mex=fig.add_subplot(221)
sb.barplot(x=df.Expect,y=df.Mutual_Funds)
plt.title("Mutual_Funds")


mex=fig.add_subplot(222)
sb.barplot(x=df.Expect,y=df.Equity_Market)
plt.title("Equity_market")


mex=fig.add_subplot(223)
sb.barplot(x=df.Expect,y=df.Debentures)
plt.title("Debentures")


mex=fig.add_subplot(224)
sb.barplot(x=df.Expect,y=df.Government_Bonds)
plt.title("Government_Bonds")
plt.show()

# %%
f=df.groupby(["Investment_Avenues","Expect"])
f.groups

# %%
p=f.get_group(('No', '20%-30%'))
p

# %%
q=f.get_group(('No', '30%-40%'))
q

# %%
r=f.get_group(('Yes', '10%-20%'))
r

# %%
s=f.get_group(('Yes', '20%-30%'))
s

# %%
t=f.get_group(('Yes', '30%-40%'))
t

# %% [markdown]
# Explore expection column & count the gender distribution depend on  different expections then I analyzed 20%_30%  expect is very high participants.ALSO Different invesment avenues and then list is displyed.

# %% [markdown]
# # Task 10: Correlation Analysis

# %%
fig=plt.figure(figsize=[10,10])
a1=fig.add_subplot(221)
sb.scatterplot(x=df.Duration,y=df.age)


a1=fig.add_subplot(222)
sb.scatterplot(x=df.Expect,y=df.age)


plt.show()

# %% [markdown]
# I Analyzed correlation between Duration and Expect with respect  to age by Scatter plot.

# %% [markdown]
# # Conclusion

# %% [markdown]
#  * I identified neumeric columns like age, mutual_funds,equity_market...etc and calculated mean,median,std,min,max..etc by using describe(),mean(),medium(),std(),to_numeric() methods.
#
#
#  *  Analyzed invesment avenues by using plots and from this graph we can see that most of the invesment in gold and then goverment _bonds therefore ,I prefred invesment Avenue  gold and goverment_bonds.
#
#
#
#  * Analyzed invesment avenues by using plots and from this graph we can see that most of the invesment in gold and then goverment _bonds therefore ,I prefred invesment Avenue  gold and goverment_bonds and also frequency is displayed in above every plot.
#
#
#
#  * equity_market capital Appreciation is one reason of most of the persons.
#     and then better Returns in Mutual_Funds and Risk free in fixed_Deposite and assured return in goverment_bonds and also goverment_bonds tax incentives is very low.
#
#
#
#  * I analyzed most of the participants saving objectives is Retirement Plan.
#
#
#  * Financial Consultants source is useful for most of the partcipants by using piechart.
#
#
#  * I also analyzed the common source data and dislayed by using barplot based on different types to invesment Avenues.
#
#
#  * Explore expection column & count the gender distribution depend on  different expections then I analyzed 20%_30%  expect is very high participants.ALSO Different invesment avenues and then list is displyed.
#
#
#  * I Analyzed correlation between Duration and Expect with respect to age by Scatter plot.
